# %%
import tweepy
from twitter_authentication import bearer_token
import time
import pandas as pd
import json 
import pickle
import folium
from folium.plugins import MarkerCluster
import json
import csv
from pathlib import Path
import glob, os, json

# %%
client = tweepy.Client(bearer_token, wait_on_rate_limit=True)

# %%
def get_tweets(place_dict = {},
               user_dict = {},
               tweet_dict = {},
                next_token = None,
               alz_tweets = [], 
                query = 'alzheimers disease -is:retweet place_country:US',
              user_fields = ['username', 'public_metrics', 'description', 'location'],
              place_fields = ['place_type', 'geo'],
              tweet_fields = ['created_at', 'geo', 'public_metrics', 'text'],
              expansions = ['author_id', 'geo.place_id'],
              start_time = '2022-01-01T00:00:00Z',
               end_time = '2023-01-15T00:00:00Z'
              ):
    place_keys= ["full_name", 'id', 'contained_within', 'country', 'country_code', 'geo', 'name', 'place_type' ]
    user_keys= ['id', 'name', 'username', 'created_at', 
            'description', "entities", 'location', 'pinned_tweet_id', 
            'profile_image_url', 'protected', 'public_metrics', 'url', 'verified', 'withheld']
    tweet_keys = ['id', 'text', 'author_id', 'context_annotations',
             'conversation_id', 'entities', 'in_reply_to_user_id', 'lang',
             'non_public_metrics', 'organic_metrics', 'possibly_sensitive',
             'promoted_metrics', 'public_metrics', 'referenced_tweets', 'reply_settings',
             'source', 'withheld']    


    for tweet in tweepy.Paginator(client.search_all_tweets, 
                                     query = query,
                                     user_fields = user_fields,
                                     place_fields = place_fields,
                                     tweet_fields = tweet_fields,
                                     expansions = expansions,
                                     start_time = start_time,
                                     end_time = end_time,
                                  pagination_token = next_token,
                                  max_results=500):
        time.sleep(1)
        alz_tweets.append(tweet)
    
    
    # Loop through each response object
    for response in alz_tweets:
        # Take all of the users, and put them into a dictionary of dictionaries with the info we want to keep
        for place in response.includes['places']:
            place_obj = {}
            for key in place_keys:
                place_obj[key] = place[key]
            place_dict[place_obj['id']] = place_obj
        for user in response.includes['users']:
            user_obj = {}
            for key in user_keys:
                user_obj[key] = user[key]
            user_dict[user_obj['id']] = user_obj

        for tweet in response.data:
            tweet_obj = {}
            for key in tweet_keys:
                tweet_obj[key] = getattr(tweet, key)
            tweet_dict[tweet_obj['id']] = tweet_obj
    
    return place_dict, user_dict, tweet_dict, next_token, alz_tweets

# %%
next_token = None
place_dict = {}
user_dict = {}
tweet_dict = {}
alz_tweets = []



place_dict, user_dict, tweet_dict, next_token, alz_tweets = get_tweets(place_dict,user_dict,tweet_dict, next_token, alz_tweets)

# %%
response = alz_tweets[0]

# %%
for tweet in response.data:
    print(dict(tweet))
    break
# Out:
# {'edit_history_tweet_ids': [1613926491200552961], 'text': 'Neuroscientists reveal how a toxic form of tau protein, #taupT217, spreads through the brain as #Alzheimers disease progresses\n\nhttps://t.co/LkvPgdlntB', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 44}, 'id': 1613926491200552961, 'geo': {'place_id': 'ab2f2fac83aa388d'}, 'author_id': 1036037388, 'created_at': datetime.datetime(2023, 1, 13, 15, 50, 35, tzinfo=datetime.timezone.utc)}

# %%
for place in response.includes['places']:
    print(dict(place))
# Out:
# {'full_name': 'Oakland, CA', 'geo': {'type': 'Feature', 'bbox': [-122.34266, 37.699279, -122.114711, 37.8847092], 'properties': {}}, 'id': 'ab2f2fac83aa388d', 'place_type': 'city'}
# {'full_name': 'Washington, DC', 'geo': {'type': 'Feature', 'bbox': [-77.119401, 38.801826, -76.909396, 38.9953797], 'properties': {}}, 'id': '01fbe706f872cb32', 'place_type': 'city'}
# {'full_name': 'Rock Springs, WY', 'geo': {'type': 'Feature', 'bbox': [-109.282237, 41.5595061, -109.192506, 41.633358], 'properties': {}}, 'id': '5db2aef731e97df0', 'place_type': 'city'}
# {'full_name': 'Macon, GA', 'geo': {'type': 'Feature', 'bbox': [-83.786106, 32.7528097, -83.522053, 32.944825], 'properties': {}}, 'id': '11a2c1d62d4084d1', 'place_type': 'city'}
# {'full_name': 'North Carolina, USA', 'geo': {'type': 'Feature', 'bbox': [-84.3219475, 33.752879, -75.40012, 36.588118], 'properties': {}}, 'id': '3b98b02fba3f9753', 'place_type': 'admin'}
# {'full_name': 'Novato, CA', 'geo': {'type': 'Feature', 'bbox': [-122.62422, 38.039015, -122.486658, 38.147701], 'properties': {}}, 'id': '3b0eea538598dc42', 'place_type': 'city'}
# {'full_name': 'Whitehall, OH', 'geo': {'type': 'Feature', 'bbox': [-82.91273, 39.950926, -82.851156, 39.986808], 'properties': {}}, 'id': '0fdd28012cbb8a2d', 'place_type': 'city'}
# {'full_name': 'San Diego, CA', 'geo': {'type': 'Feature', 'bbox': [-117.282538, 32.53962, -116.9274403, 33.0804044], 'properties': {}}, 'id': 'a592bd6ceb1319f7', 'place_type': 'city'}
# {'full_name': 'Pleasanton, CA', 'geo': {'type': 'Feature', 'bbox': [-121.956864, 37.621859, -121.7986057, 37.704036], 'properties': {}}, 'id': 'ad4876a662119b74', 'place_type': 'city'}
# {'full_name': 'Pittsburgh, PA', 'geo': {'type': 'Feature', 'bbox': [-80.095586, 40.3615796, -79.8657933, 40.501198], 'properties': {}}, 'id': '946ccd22e1c9cda1', 'place_type': 'city'}
# {'full_name': 'Florida, USA', 'geo': {'type': 'Feature', 'bbox': [-87.634643, 24.396308, -79.974307, 31.001056], 'properties': {}}, 'id': '4ec01c9dbc693497', 'place_type': 'admin'}
# {'full_name': 'Vinings, GA', 'geo': {'type': 'Feature', 'bbox': [-84.487242, 33.841705, -84.4542161, 33.8811], 'properties': {}}, 'id': 'fee8047a46fbdfc8', 'place_type': 'city'}
# {'full_name': 'Lakeland, FL', 'geo': {'type': 'Feature', 'bbox': [-82.042715, 27.968692, -81.902695, 28.13051], 'properties': {}}, 'id': '3f7a925ec706ea48', 'place_type': 'city'}
# {'full_name': 'San Francisco, CA', 'geo': {'type': 'Feature', 'bbox': [-122.514926, 37.708075, -122.357031, 37.833238], 'properties': {}}, 'id': '5a110d312052166f', 'place_type': 'city'}
# {'full_name': 'Delray Beach, FL', 'geo': {'type': 'Feature', 'bbox': [-80.1309396, 26.420813, -80.05542, 26.491482], 'properties': {}}, 'id': 'b4a0e9082dcc8436', 'place_type': 'city'}
# {'full_name': 'Texas, USA', 'geo': {'type': 'Feature', 'bbox': [-106.645646, 25.837092, -93.508131, 36.500695], 'properties': {}}, 'id': 'e0060cda70f5f341', 'place_type': 'admin'}
# {'full_name': 'Chicago, IL', 'geo': {'type': 'Feature', 'bbox': [-87.940033, 41.644102, -87.523993, 42.0230669], 'properties': {}}, 'id': '1d9a5370a355ab0c', 'place_type': 'city'}
# {'full_name': 'New Jersey, USA', 'geo': {'type': 'Feature', 'bbox': [-75.563587, 38.788657, -73.88506, 41.357424], 'properties': {}}, 'id': '65b4760a2b411e11', 'place_type': 'admin'}
# {'full_name': 'Sacramento, CA', 'geo': {'type': 'Feature', 'bbox': [-121.576613, 38.43792, -121.362715, 38.6855236], 'properties': {}}, 'id': 'b71fac2ee9792cbe', 'place_type': 'city'}
# {'full_name': 'Boca Raton, FL', 'geo': {'type': 'Feature', 'bbox': [-80.2039913, 26.320692, -80.065981, 26.427259], 'properties': {}}, 'id': 'd1cd39353c51904d', 'place_type': 'city'}
# {'full_name': 'Paradise Valley, AZ', 'geo': {'type': 'Feature', 'bbox': [-112.014232, 33.508746, -111.916817, 33.582629], 'properties': {}}, 'id': '9a99329bbb5d8bba', 'place_type': 'city'}
# {'full_name': 'South Dakota, USA', 'geo': {'type': 'Feature', 'bbox': [-104.05774, 42.479636, -96.43659, 45.945379], 'properties': {}}, 'id': 'd06e595eb3733f42', 'place_type': 'admin'}
# {'full_name': 'Kenner, LA', 'geo': {'type': 'Feature', 'bbox': [-90.285434, 29.969126, -90.221258, 30.049577], 'properties': {}}, 'id': '6e5c7d7cfdf8a6b7', 'place_type': 'city'}
# {'full_name': 'Laurel Hollow, NY', 'geo': {'type': 'Feature', 'bbox': [-73.494416, 40.83702, -73.455336, 40.879543], 'properties': {}}, 'id': 'dfe9991fc7f69a4f', 'place_type': 'city'}
# {'full_name': 'Mystic, CT', 'geo': {'type': 'Feature', 'bbox': [-71.978961, 41.320856, -71.934748, 41.40432], 'properties': {}}, 'id': 'f0b6719e74702740', 'place_type': 'city'}
# {'full_name': 'Hanover, NH', 'geo': {'type': 'Feature', 'bbox': [-72.30265, 43.684229, -72.250859, 43.733431], 'properties': {}}, 'id': '285263829aa8055f', 'place_type': 'city'}
# {'full_name': 'Las Vegas, NV', 'geo': {'type': 'Feature', 'bbox': [-115.384091, 36.129459, -115.062159, 36.336371], 'properties': {}}, 'id': '5c2b5e46ab891f07', 'place_type': 'city'}
# {'full_name': 'Nevada, USA', 'geo': {'type': 'Feature', 'bbox': [-120.00574, 35.002086, -114.039649, 42.002208], 'properties': {}}, 'id': 'd374fb61a20fb74f', 'place_type': 'admin'}
# {'full_name': 'Yuma, AZ', 'geo': {'type': 'Feature', 'bbox': [-114.710936, 32.601699, -114.458569, 32.734737], 'properties': {}}, 'id': '607358f5dbace76a', 'place_type': 'city'}
# {'full_name': 'Providence, RI', 'geo': {'type': 'Feature', 'bbox': [-71.4741855, 41.772455, -71.369479, 41.861713], 'properties': {}}, 'id': '7b93be1d864cedbb', 'place_type': 'city'}
# {'full_name': 'New York, NY', 'geo': {'type': 'Feature', 'bbox': [-74.255641, 40.495865, -73.699793, 40.91533], 'properties': {}}, 'id': '27485069891a7938', 'place_type': 'admin'}
# {'full_name': 'Nashua, NH', 'geo': {'type': 'Feature', 'bbox': [-71.5749, 42.7000873, -71.4333342, 42.805852], 'properties': {}}, 'id': 'db6cee8d55fe4a29', 'place_type': 'city'}
# {'full_name': 'New Orleans, LA', 'geo': {'type': 'Feature', 'bbox': [-90.137908, 29.889574, -89.884108, 30.075628], 'properties': {}}, 'id': 'dd3b100831dd1763', 'place_type': 'city'}
# {'full_name': 'Colesville, MD', 'geo': {'type': 'Feature', 'bbox': [-77.040246, 39.055572, -76.97471, 39.125337], 'properties': {}}, 'id': '09d38e8e348e39ba', 'place_type': 'city'}
# {'full_name': 'Illinois, USA', 'geo': {'type': 'Feature', 'bbox': [-91.51308, 36.970298, -87.019935, 42.508303], 'properties': {}}, 'id': 'f54a2170ff4b15f7', 'place_type': 'admin'}
# {'full_name': 'Austin, TX', 'geo': {'type': 'Feature', 'bbox': [-97.928935, 30.127892, -97.5805133, 30.5187994], 'properties': {}}, 'id': 'c3f37afa9efcf94b', 'place_type': 'city'}
# {'full_name': 'Wisconsin, USA', 'geo': {'type': 'Feature', 'bbox': [-92.889433, 42.491921, -86.24955, 47.309715], 'properties': {}}, 'id': '7dc5c6d3bfb10ccc', 'place_type': 'admin'}
# {'full_name': 'Tempe, AZ', 'geo': {'type': 'Feature', 'bbox': [-111.979047, 33.3199453, -111.877237, 33.465823], 'properties': {}}, 'id': '7cb7440bcf83d464', 'place_type': 'city'}
# {'full_name': 'Manhattan, NY', 'geo': {'type': 'Feature', 'bbox': [-74.026675, 40.683935, -73.910408, 40.877483], 'properties': {}}, 'id': '01a9a39529b27f36', 'place_type': 'city'}
# {'full_name': 'Stockton, CA', 'geo': {'type': 'Feature', 'bbox': [-121.4168716, 37.883347, -121.183979, 38.078305], 'properties': {}}, 'id': 'd98e7ce217ade2c5', 'place_type': 'city'}
# {'full_name': 'San Jose, CA', 'geo': {'type': 'Feature', 'bbox': [-122.035311, 37.193164, -121.71215, 37.469154], 'properties': {}}, 'id': '7d62cffe6f98f349', 'place_type': 'city'}
# {'full_name': 'Milwaukee, WI', 'geo': {'type': 'Feature', 'bbox': [-88.070827, 42.920822, -87.863758, 43.1926225], 'properties': {}}, 'id': '2a93711775303f90', 'place_type': 'city'}
# {'full_name': 'Conway, AR', 'geo': {'type': 'Feature', 'bbox': [-92.537713, 35.018058, -92.323965, 35.128165], 'properties': {}}, 'id': '90407ba247350183', 'place_type': 'city'}
# {'full_name': 'Pooler, GA', 'geo': {'type': 'Feature', 'bbox': [-81.338145, 32.007509, -81.197739, 32.191443], 'properties': {}}, 'id': 'bc1dbfe09834a716', 'place_type': 'city'}
# {'full_name': 'Indiana, USA', 'geo': {'type': 'Feature', 'bbox': [-88.097892, 37.771743, -84.78458, 41.761368], 'properties': {}}, 'id': '1010ecfa7d3a40f8', 'place_type': 'admin'}
# {'full_name': 'Mesa, AZ', 'geo': {'type': 'Feature', 'bbox': [-111.894548, 33.306275, -111.5805834, 33.505234], 'properties': {}}, 'id': '44d207663001f00b', 'place_type': 'city'}
# {'full_name': 'Phoenix, AZ', 'geo': {'type': 'Feature', 'bbox': [-112.3239143, 33.29026, -111.9254391, 33.8154652], 'properties': {}}, 'id': '5c62ffb0f0f3479d', 'place_type': 'city'}
# {'full_name': 'Newark, NJ', 'geo': {'type': 'Feature', 'bbox': [-74.25136, 40.679997, -74.118336, 40.788991], 'properties': {}}, 'id': 'fa3435044b52ecc7', 'place_type': 'city'}
# {'full_name': 'Lake St Louis, MO', 'geo': {'type': 'Feature', 'bbox': [-90.827471, 38.740475, -90.745133, 38.818803], 'properties': {}}, 'id': '49d90677d36d121f', 'place_type': 'city'}
# {'full_name': 'East Point, GA', 'geo': {'type': 'Feature', 'bbox': [-84.5355341, 33.609487, -84.4150479, 33.7056846], 'properties': {}}, 'id': 'dfb4df427ea8a2d6', 'place_type': 'city'}
# {'full_name': 'Miami Heights, OH', 'geo': {'type': 'Feature', 'bbox': [-84.747266, 39.143503, -84.683884, 39.192268], 'properties': {}}, 'id': '01fc64883cc9eb37', 'place_type': 'city'}
# {'full_name': 'Temecula, CA', 'geo': {'type': 'Feature', 'bbox': [-117.184394, 33.447541, -117.054639, 33.554501], 'properties': {}}, 'id': 'f95304ef80fecc3f', 'place_type': 'city'}
# {'full_name': 'Boston, MA', 'geo': {'type': 'Feature', 'bbox': [-71.191421, 42.227797, -70.986004, 42.399542], 'properties': {}}, 'id': '67b98f17fdcf20be', 'place_type': 'city'}
# {'full_name': 'Pittsfield, MI', 'geo': {'type': 'Feature', 'bbox': [-83.7850832, 42.142414, -83.641471, 42.2594116], 'properties': {}}, 'id': '00d73c6d35bf8b5a', 'place_type': 'city'}
# {'full_name': 'Kentucky, USA', 'geo': {'type': 'Feature', 'bbox': [-89.57151, 36.497129, -81.964971, 39.147359], 'properties': {}}, 'id': '6ffcf3b0b904bbcb', 'place_type': 'admin'}
# {'full_name': 'Amesbury, MA', 'geo': {'type': 'Feature', 'bbox': [-71.004401, 42.821746, -70.899283, 42.8868114], 'properties': {}}, 'id': '01f2e34d113355c2', 'place_type': 'city'}
# {'full_name': 'Santa Clara, CA', 'geo': {'type': 'Feature', 'bbox': [-122.005597, 37.322943, -121.930045, 37.419037], 'properties': {}}, 'id': '4b58830723ec6371', 'place_type': 'city'}
# {'full_name': 'St Paul, MN', 'geo': {'type': 'Feature', 'bbox': [-93.207783, 44.8907521, -93.003514, 44.992279], 'properties': {}}, 'id': '60e2c37980197297', 'place_type': 'city'}
# {'full_name': 'Albuquerque, NM', 'geo': {'type': 'Feature', 'bbox': [-106.7916912, 35.0158912, -106.473745, 35.218114], 'properties': {}}, 'id': '813a485b26b8dae2', 'place_type': 'city'}
# {'full_name': 'Springfield, MA', 'geo': {'type': 'Feature', 'bbox': [-72.620117, 42.06398, -72.471052, 42.162145], 'properties': {}}, 'id': '9f4583bf6dae13c4', 'place_type': 'city'}
# {'full_name': 'Los Angeles, CA', 'geo': {'type': 'Feature', 'bbox': [-118.668404, 33.704538, -118.155409, 34.337041], 'properties': {}}, 'id': '3b77caf94bfc81fe', 'place_type': 'city'}
# {'full_name': 'San Antonio, TX', 'geo': {'type': 'Feature', 'bbox': [-98.778559, 29.141956, -98.302744, 29.693046], 'properties': {}}, 'id': '3df4f427b5a60fea', 'place_type': 'city'}
# {'full_name': 'North Syracuse, NY', 'geo': {'type': 'Feature', 'bbox': [-76.1708779, 43.117166, -76.073088, 43.151251], 'properties': {}}, 'id': 'ad1832ff3a023a30', 'place_type': 'city'}
# {'full_name': 'Indianapolis, IN', 'geo': {'type': 'Feature', 'bbox': [-86.348441, 39.631677, -85.937404, 39.927448], 'properties': {}}, 'id': '018929347840059e', 'place_type': 'city'}
# {'full_name': 'Queens, NY', 'geo': {'type': 'Feature', 'bbox': [-73.962582, 40.541722, -73.699793, 40.8000371], 'properties': {}}, 'id': '00c39537733fa112', 'place_type': 'city'}
# {'full_name': 'Portland, OR', 'geo': {'type': 'Feature', 'bbox': [-122.7900653, 45.421863, -122.471751, 45.6509405], 'properties': {}}, 'id': 'ac88a4f17a51c7fc', 'place_type': 'city'}
# {'full_name': 'Cambridge, MA', 'geo': {'type': 'Feature', 'bbox': [-71.160356, 42.352429, -71.064398, 42.4039663], 'properties': {}}, 'id': '8193d87541f11dfb', 'place_type': 'city'}
# {'full_name': 'St Petersburg, FL', 'geo': {'type': 'Feature', 'bbox': [-82.758209, 27.694323, -82.587597, 27.8971155], 'properties': {}}, 'id': '5d231ed8656fcf5a', 'place_type': 'city'}
# {'full_name': 'Mendota Heights, MN', 'geo': {'type': 'Feature', 'bbox': [-93.199772, 44.861156, -93.105788, 44.919831], 'properties': {}}, 'id': '8a266a4cb64f3013', 'place_type': 'city'}
# {'full_name': 'Pineville, NC', 'geo': {'type': 'Feature', 'bbox': [-80.919951, 35.053241, -80.85395, 35.109799], 'properties': {}}, 'id': 'c5b5da4969964536', 'place_type': 'city'}
# {'full_name': 'Brooklyn, NY', 'geo': {'type': 'Feature', 'bbox': [-74.041878, 40.570842, -73.855673, 40.739434], 'properties': {}}, 'id': '011add077f4d2da3', 'place_type': 'city'}
# {'full_name': 'Oklahoma City, OK', 'geo': {'type': 'Feature', 'bbox': [-97.768683, 35.290722, -97.335639, 35.674965], 'properties': {}}, 'id': '9531d4e3bbafc09d', 'place_type': 'city'}
# {'full_name': 'Anchorage, AK', 'geo': {'type': 'Feature', 'bbox': [-150.0352589, 61.043884, -149.48233, 61.426201], 'properties': {}}, 'id': '7a863bb88e5bb33c', 'place_type': 'city'}
# {'full_name': 'Ross Township, PA', 'geo': {'type': 'Feature', 'bbox': [-80.0647047, 40.487357, -79.985516, 40.555021], 'properties': {}}, 'id': 'f6514a91adf25ce4', 'place_type': 'city'}
# {'full_name': 'Virginia, USA', 'geo': {'type': 'Feature', 'bbox': [-83.67529, 36.540739, -75.16644, 39.466012], 'properties': {}}, 'id': '5635c19c2b5078d1', 'place_type': 'admin'}
# {'full_name': 'Billings, MT', 'geo': {'type': 'Feature', 'bbox': [-108.6928791, 45.723722, -108.432965, 45.8711694], 'properties': {}}, 'id': '662aa8db4557a744', 'place_type': 'city'}
# {'full_name': 'Potomac, MD', 'geo': {'type': 'Feature', 'bbox': [-77.248462, 38.971077, -77.1418208, 39.0693022], 'properties': {}}, 'id': '6a83705c6ef0b6b0', 'place_type': 'city'}
# {'full_name': 'Virginia Beach, VA', 'geo': {'type': 'Feature', 'bbox': [-76.22808, 36.672684, -75.9118121, 36.932399], 'properties': {}}, 'id': '84229b03659050aa', 'place_type': 'city'}
# {'full_name': 'Port Hueneme, CA', 'geo': {'type': 'Feature', 'bbox': [-119.221552, 34.138118, -119.186037, 34.181304], 'properties': {}}, 'id': 'f2dabb4da43780ea', 'place_type': 'city'}
# {'full_name': 'Orlando, FL', 'geo': {'type': 'Feature', 'bbox': [-81.507905, 28.3882177, -81.2276403, 28.615139], 'properties': {}}, 'id': '55b4f9e5c516e0b6', 'place_type': 'city'}
# {'full_name': 'Georgia, USA', 'geo': {'type': 'Feature', 'bbox': [-85.605166, 30.355644, -80.742567, 35.000771], 'properties': {}}, 'id': '7142eb97ae21e839', 'place_type': 'admin'}
# {'full_name': 'Artesia, CA', 'geo': {'type': 'Feature', 'bbox': [-118.091312, 33.853432, -118.0689157, 33.880386], 'properties': {}}, 'id': 'b82c98fb6806ceb9', 'place_type': 'city'}
# {'full_name': 'Seattle, WA', 'geo': {'type': 'Feature', 'bbox': [-122.436232, 47.4953154, -122.2249728, 47.734319], 'properties': {}}, 'id': '300bcc6e23a88361', 'place_type': 'city'}
# {'full_name': 'Bolingbrook, IL', 'geo': {'type': 'Feature', 'bbox': [-88.18516, 41.630746, -88.0269003, 41.7359316], 'properties': {}}, 'id': '0991d757989cef56', 'place_type': 'city'}
# {'full_name': 'Frisco, TX', 'geo': {'type': 'Feature', 'bbox': [-96.937783, 33.081206, -96.7327146, 33.219073], 'properties': {}}, 'id': '00c3e46c3d0cac08', 'place_type': 'city'}
# {'full_name': 'Fountainebleau, FL', 'geo': {'type': 'Feature', 'bbox': [-80.386249, 25.761172, -80.3204156, 25.783404], 'properties': {}}, 'id': '0185fd6875f1815c', 'place_type': 'city'}
# {'full_name': 'Gastonia, NC', 'geo': {'type': 'Feature', 'bbox': [-81.281029, 35.173615, -81.083206, 35.305409], 'properties': {}}, 'id': 'e7aa53e3e1531b99', 'place_type': 'city'}
# {'full_name': 'Charlotte, NC', 'geo': {'type': 'Feature', 'bbox': [-81.046876, 35.001706, -80.646695, 35.416412], 'properties': {}}, 'id': '512a8a4a4c4b4be0', 'place_type': 'city'}
# {'full_name': 'Pennsylvania, USA', 'geo': {'type': 'Feature', 'bbox': [-80.519851, 39.719801, -74.689517, 42.516072], 'properties': {}}, 'id': 'dd9c503d6c35364b', 'place_type': 'admin'}
# {'full_name': 'East Lake, FL', 'geo': {'type': 'Feature', 'bbox': [-82.73371, 28.04581, -82.668583, 28.1733149], 'properties': {}}, 'id': 'a1261e1ada14bf62', 'place_type': 'city'}
# {'full_name': 'Washington, PA', 'geo': {'type': 'Feature', 'bbox': [-80.327525, 40.131709, -80.208588, 40.200796], 'properties': {}}, 'id': '0097a1de4d520b9a', 'place_type': 'city'}
# {'full_name': 'Cape Girardeau, MO', 'geo': {'type': 'Feature', 'bbox': [-89.6285806, 37.255486, -89.490907, 37.3787], 'properties': {}}, 'id': '19a69af030945159', 'place_type': 'city'}
# {'full_name': 'Birmingham, AL', 'geo': {'type': 'Feature', 'bbox': [-86.967333, 33.405025, -86.620501, 33.67945], 'properties': {}}, 'id': '92220986b9dfd67d', 'place_type': 'city'}
# {'full_name': 'Lake Grove, NY', 'geo': {'type': 'Feature', 'bbox': [-73.13217, 40.835174, -73.102764, 40.883089], 'properties': {}}, 'id': '43545465269e5d09', 'place_type': 'city'}
# {'full_name': 'Carmel, IN', 'geo': {'type': 'Feature', 'bbox': [-86.241245, 39.926048, -86.023652, 40.000451], 'properties': {}}, 'id': 'eca35cbd75f0a1e6', 'place_type': 'city'}
# {'full_name': 'Corona, CA', 'geo': {'type': 'Feature', 'bbox': [-117.672915, 33.802102, -117.498401, 33.916084], 'properties': {}}, 'id': '5e4b6834e36e68fa', 'place_type': 'city'}
# {'full_name': 'Michigan, USA', 'geo': {'type': 'Feature', 'bbox': [-90.4181075, 41.696088, -82.122971, 48.306272], 'properties': {}}, 'id': '67d92742f1ebf307', 'place_type': 'admin'}
# {'full_name': 'Davis, CA', 'geo': {'type': 'Feature', 'bbox': [-121.803252, 38.526843, -121.675074, 38.590264], 'properties': {}}, 'id': '1994142e26ba7127', 'place_type': 'city'}
# {'full_name': 'California, USA', 'geo': {'type': 'Feature', 'bbox': [-124.482003, 32.528832, -114.131212, 42.009519], 'properties': {}}, 'id': 'fbd6d2f5a4e4a15e', 'place_type': 'admin'}
# {'full_name': 'Ann Arbor, MI', 'geo': {'type': 'Feature', 'bbox': [-83.800262, 42.215087, -83.659681, 42.326592], 'properties': {}}, 'id': '92b2158a6d509767', 'place_type': 'city'}
# {'full_name': 'Doral, FL', 'geo': {'type': 'Feature', 'bbox': [-80.41729, 25.780974, -80.3210162, 25.870313], 'properties': {}}, 'id': '053ab8e6678199ed', 'place_type': 'city'}
# {'full_name': 'La Verkin, UT', 'geo': {'type': 'Feature', 'bbox': [-113.287325, 37.189811, -113.263831, 37.222346], 'properties': {}}, 'id': '649e80e2de8e64ad', 'place_type': 'city'}
# {'full_name': 'Tennessee, USA', 'geo': {'type': 'Feature', 'bbox': [-90.310298, 34.982924, -81.646901, 36.678119], 'properties': {}}, 'id': '7f7d58e5229c6b6c', 'place_type': 'admin'}
# {'full_name': 'Tallahassee, FL', 'geo': {'type': 'Feature', 'bbox': [-84.386548, 30.365093, -84.1458, 30.587338], 'properties': {}}, 'id': 'ecbe2aea853af44e', 'place_type': 'city'}
# {'full_name': 'Henrietta, NY', 'geo': {'type': 'Feature', 'bbox': [-77.730299, 43.017206, -77.553575, 43.096872], 'properties': {}}, 'id': '00c60988621e2c71', 'place_type': 'city'}
# {'full_name': 'Philadelphia, PA', 'geo': {'type': 'Feature', 'bbox': [-75.280284, 39.871811, -74.955712, 40.13792], 'properties': {}}, 'id': 'e4a0d228eb6be76b', 'place_type': 'city'}
# {'full_name': 'Bellaire, TX', 'geo': {'type': 'Feature', 'bbox': [-95.4846466, 29.6893718, -95.447422, 29.725996], 'properties': {}}, 'id': 'bc39561011b12bc6', 'place_type': 'city'}
# {'full_name': 'St Louis, MO', 'geo': {'type': 'Feature', 'bbox': [-90.3205158, 38.5331934, -90.175132, 38.774349], 'properties': {}}, 'id': '0570f015c264cbd9', 'place_type': 'city'}
# {'full_name': 'Nashville, TN', 'geo': {'type': 'Feature', 'bbox': [-87.022482, 35.9945681, -86.560616, 36.405448], 'properties': {}}, 'id': '00ab941b685334e3', 'place_type': 'city'}
# {'full_name': 'Monroe, LA', 'geo': {'type': 'Feature', 'bbox': [-92.135057, 32.429655, -92.018346, 32.612831], 'properties': {}}, 'id': 'e60ab9aacc0e96af', 'place_type': 'city'}
# {'full_name': 'Daytona Beach, FL', 'geo': {'type': 'Feature', 'bbox': [-81.133668, 29.127565, -81.003444, 29.2528814], 'properties': {}}, 'id': '5876e96f70283826', 'place_type': 'city'}
# {'full_name': 'Chapel Hill, NC', 'geo': {'type': 'Feature', 'bbox': [-79.0831529, 35.869376, -78.968887, 35.969507], 'properties': {}}, 'id': '23ebe811ea93fd41', 'place_type': 'city'}
# {'full_name': 'Great Neck, NY', 'geo': {'type': 'Feature', 'bbox': [-73.75756, 40.793334, -73.710409, 40.812799], 'properties': {}}, 'id': 'c9f2dd04c9ba49c0', 'place_type': 'city'}
# {'full_name': 'Palm Valley, FL', 'geo': {'type': 'Feature', 'bbox': [-81.429238, 30.133473, -81.36028, 30.252933], 'properties': {}}, 'id': '6416fd85ecf9cf8b', 'place_type': 'city'}
# {'full_name': 'Alexandria, VA', 'geo': {'type': 'Feature', 'bbox': [-77.144435, 38.789907, -77.037304, 38.8448531], 'properties': {}}, 'id': 'd6819fe60643ebc1', 'place_type': 'city'}
# {'full_name': 'North Druid Hills, GA', 'geo': {'type': 'Feature', 'bbox': [-84.348497, 33.799908, -84.303938, 33.840414], 'properties': {}}, 'id': '590c1000bfb45cf6', 'place_type': 'city'}
# {'full_name': 'Houston, TX', 'geo': {'type': 'Feature', 'bbox': [-95.823268, 29.522325, -95.069705, 30.1546646], 'properties': {}}, 'id': '1c69a67ad480e1b1', 'place_type': 'city'}
# {'full_name': 'Fremont, CA', 'geo': {'type': 'Feature', 'bbox': [-122.069956, 37.454962, -121.889098, 37.592327], 'properties': {}}, 'id': '30344aecffe6a491', 'place_type': 'city'}
# {'full_name': 'Encinitas, CA', 'geo': {'type': 'Feature', 'bbox': [-117.312091, 32.999469, -117.195721, 33.090549], 'properties': {}}, 'id': '1f6b47c3f3352385', 'place_type': 'city'}
# {'full_name': 'Montclair, NJ', 'geo': {'type': 'Feature', 'bbox': [-74.237314, 40.788029, -74.182684, 40.86178], 'properties': {}}, 'id': 'bceb8153865c4a49', 'place_type': 'city'}
# {'full_name': 'Lynnwood, WA', 'geo': {'type': 'Feature', 'bbox': [-122.3377166, 47.802196, -122.262542, 47.8537715], 'properties': {}}, 'id': '3912e7cd4cf62c39', 'place_type': 'city'}
# {'full_name': 'West Palm Beach, FL', 'geo': {'type': 'Feature', 'bbox': [-80.2006, 26.644671, -80.044639, 26.7991205], 'properties': {}}, 'id': '4de072969805ac41', 'place_type': 'city'}
# {'full_name': 'Oswego, NY', 'geo': {'type': 'Feature', 'bbox': [-76.565589, 43.428101, -76.437307, 43.494352], 'properties': {}}, 'id': '2bf0b14f23e6d6b8', 'place_type': 'city'}
# {'full_name': 'Lacey, WA', 'geo': {'type': 'Feature', 'bbox': [-122.839662, 46.9594626, -122.691155, 47.119369], 'properties': {}}, 'id': '0084a2ce4881fa56', 'place_type': 'city'}
# {'full_name': 'Twinsburg, OH', 'geo': {'type': 'Feature', 'bbox': [-81.489172, 41.276327, -81.4008687, 41.349821], 'properties': {}}, 'id': '65aa0cebdf1cd524', 'place_type': 'city'}
# {'full_name': 'Gainesville, FL', 'geo': {'type': 'Feature', 'bbox': [-82.421473, 29.600496, -82.239066, 29.745847], 'properties': {}}, 'id': '7dda05213481260c', 'place_type': 'city'}
# {'full_name': 'Los Banos, CA', 'geo': {'type': 'Feature', 'bbox': [-120.879833, 37.033745, -120.803053, 37.088185], 'properties': {}}, 'id': 'b1b6fc646de75904', 'place_type': 'city'}
# {'full_name': 'Lexington, SC', 'geo': {'type': 'Feature', 'bbox': [-81.339579, 33.9269923, -81.1488, 34.043912], 'properties': {}}, 'id': '00ae272d6d0d28fe', 'place_type': 'city'}
# {'full_name': 'Sand Springs, OK', 'geo': {'type': 'Feature', 'bbox': [-96.1873108, 36.061052, -96.154775, 36.082362], 'properties': {}}, 'id': '688d7e828fac953f', 'place_type': 'city'}
# {'full_name': 'Maryland Heights, MO', 'geo': {'type': 'Feature', 'bbox': [-90.5008048, 38.675851, -90.407348, 38.756043], 'properties': {}}, 'id': 'fb26223d27a11fbb', 'place_type': 'city'}
# {'full_name': 'Eureka, CA', 'geo': {'type': 'Feature', 'bbox': [-124.202007, 40.7453389, -124.136897, 40.819908], 'properties': {}}, 'id': 'c201deec6d7ba944', 'place_type': 'city'}
# {'full_name': 'Gilbert, AZ', 'geo': {'type': 'Feature', 'bbox': [-111.842244, 33.204608, -111.634889, 33.3858215], 'properties': {}}, 'id': '006b48995ede9bcc', 'place_type': 'city'}
# {'full_name': 'St Augustine, FL', 'geo': {'type': 'Feature', 'bbox': [-81.344147, 29.856582, -81.26716, 29.940326], 'properties': {}}, 'id': '01b31e336c002ed7', 'place_type': 'city'}
# {'full_name': 'Jasper, FL', 'geo': {'type': 'Feature', 'bbox': [-82.964156, 30.507996, -82.939977, 30.531889], 'properties': {}}, 'id': '9fa0b7b5a43e3b4d', 'place_type': 'city'}
# {'full_name': 'Cape Coral, FL', 'geo': {'type': 'Feature', 'bbox': [-82.069567, 26.531814, -81.9041014, 26.741146], 'properties': {}}, 'id': 'fbd1502e5edce6bf', 'place_type': 'city'}
# {'full_name': 'Connecticut, USA', 'geo': {'type': 'Feature', 'bbox': [-73.727776, 40.950918, -71.786994, 42.050588], 'properties': {}}, 'id': 'e86b380cfefcced5', 'place_type': 'admin'}
# {'full_name': 'Redding, CA', 'geo': {'type': 'Feature', 'bbox': [-122.452708, 40.456935, -122.267398, 40.651054], 'properties': {}}, 'id': '7d51c8dfbb08a9de', 'place_type': 'city'}
# {'full_name': 'Wade Hampton, SC', 'geo': {'type': 'Feature', 'bbox': [-82.39106, 34.844855, -82.248664, 34.918991], 'properties': {}}, 'id': '482718a57149bdd5', 'place_type': 'city'}
# {'full_name': 'Elk Grove, CA', 'geo': {'type': 'Feature', 'bbox': [-121.4875756, 38.361325, -121.276607, 38.4817437], 'properties': {}}, 'id': '6daef4115502c39e', 'place_type': 'city'}
# {'full_name': 'Stanton, KY', 'geo': {'type': 'Feature', 'bbox': [-83.878491, 37.828434, -83.808843, 37.861838], 'properties': {}}, 'id': 'aca6820ba273cd26', 'place_type': 'city'}
# {'full_name': 'Truckee, CA', 'geo': {'type': 'Feature', 'bbox': [-120.301299, 39.307692, -120.086075, 39.3738469], 'properties': {}}, 'id': '00e2ddb9544ba5bd', 'place_type': 'city'}
# {'full_name': 'Newton, MA', 'geo': {'type': 'Feature', 'bbox': [-71.270426, 42.283041, -71.156939, 42.367744], 'properties': {}}, 'id': 'b76630ca2b2c4158', 'place_type': 'city'}
# {'full_name': 'North Lakeport, CA', 'geo': {'type': 'Feature', 'bbox': [-122.9321203, 39.061722, -122.886028, 39.121034], 'properties': {}}, 'id': '44888fa3ddd56f8c', 'place_type': 'city'}
# {'full_name': 'El Paso, TX', 'geo': {'type': 'Feature', 'bbox': [-106.634874, 31.6206683, -106.199987, 31.966068], 'properties': {}}, 'id': '6a0a3474d8c5113c', 'place_type': 'city'}
# {'full_name': 'Athens, GA', 'geo': {'type': 'Feature', 'bbox': [-83.5218655, 33.877554, -83.277693, 34.035213], 'properties': {}}, 'id': '01f9c9fd7bb1aa6b', 'place_type': 'city'}
# {'full_name': 'Savannah, GA', 'geo': {'type': 'Feature', 'bbox': [-81.188663, 31.922596, -81.03057, 32.111973], 'properties': {}}, 'id': '00e9226863a6e5a4', 'place_type': 'city'}
# {'full_name': 'Atlanta, GA', 'geo': {'type': 'Feature', 'bbox': [-84.576827, 33.6475029, -84.289385, 33.8868859], 'properties': {}}, 'id': '8173485c72e78ca5', 'place_type': 'city'}
# {'full_name': 'Metuchen, NJ', 'geo': {'type': 'Feature', 'bbox': [-74.381081, 40.5277718, -74.344981, 40.555373], 'properties': {}}, 'id': '64be9b322be0df48', 'place_type': 'city'}
# {'full_name': 'Webster, NY', 'geo': {'type': 'Feature', 'bbox': [-77.534189, 43.1963, -77.3752762, 43.267749], 'properties': {}}, 'id': '01e5198d558fc4d5', 'place_type': 'city'}
# {'full_name': 'Coon Rapids, MN', 'geo': {'type': 'Feature', 'bbox': [-93.374494, 45.118611, -93.265764, 45.212876], 'properties': {}}, 'id': '850e74c08b577616', 'place_type': 'city'}
# {'full_name': 'Cinco Ranch, TX', 'geo': {'type': 'Feature', 'bbox': [-95.8463667, 29.676113, -95.711056, 29.7678652], 'properties': {}}, 'id': '01e74c422dab6107', 'place_type': 'city'}
# {'full_name': 'Pomona, CA', 'geo': {'type': 'Feature', 'bbox': [-117.834663, 34.0182828, -117.7111706, 34.1126181], 'properties': {}}, 'id': '6f24e28976abe656', 'place_type': 'city'}
# {'full_name': 'Kalamazoo, MI', 'geo': {'type': 'Feature', 'bbox': [-85.649602, 42.215555, -85.481775, 42.365493], 'properties': {}}, 'id': '413ef5a0d23bfe4f', 'place_type': 'city'}
# {'full_name': 'Irvine, CA', 'geo': {'type': 'Feature', 'bbox': [-117.86894, 33.606077, -117.695781, 33.773387], 'properties': {}}, 'id': '3d533362cdab8107', 'place_type': 'city'}
# {'full_name': 'Cimarron Hills, CO', 'geo': {'type': 'Feature', 'bbox': [-104.7209885, 38.8317073, -104.6811019, 38.900855], 'properties': {}}, 'id': '6ba10b142c887fdb', 'place_type': 'city'}
# {'full_name': 'Santa Monica, CA', 'geo': {'type': 'Feature', 'bbox': [-118.5173575, 33.9951771, -118.443482, 34.050199], 'properties': {}}, 'id': '59612bd882018c51', 'place_type': 'city'}
# {'full_name': 'Annapolis, MD', 'geo': {'type': 'Feature', 'bbox': [-76.5533209, 38.941032, -76.468263, 38.9989], 'properties': {}}, 'id': 'aa509e938179ea44', 'place_type': 'city'}
# {'full_name': 'Antioch, CA', 'geo': {'type': 'Feature', 'bbox': [-121.860664, 37.945647, -121.732224, 38.025674], 'properties': {}}, 'id': '9b101e0451f073b6', 'place_type': 'city'}
# {'full_name': 'Elko, NV', 'geo': {'type': 'Feature', 'bbox': [-115.831165, 40.801431, -115.709259, 40.883884], 'properties': {}}, 'id': 'a3b39b40a6f077f5', 'place_type': 'city'}
# {'full_name': 'Fresno, CA', 'geo': {'type': 'Feature', 'bbox': [-119.93251, 36.648905, -119.632419, 36.923179], 'properties': {}}, 'id': '944c03c1d85ef480', 'place_type': 'city'}
# {'full_name': 'Greenacres, FL', 'geo': {'type': 'Feature', 'bbox': [-80.175957, 26.588782, -80.1123944, 26.678639], 'properties': {}}, 'id': 'be925761a3187f65', 'place_type': 'city'}
# {'full_name': 'Pullman, WA', 'geo': {'type': 'Feature', 'bbox': [-117.2132149, 46.70823, -117.095324, 46.7534141], 'properties': {}}, 'id': '6045d4aebc672078', 'place_type': 'city'}
# {'full_name': 'Woodland, CA', 'geo': {'type': 'Feature', 'bbox': [-121.802695, 38.640692, -121.709862, 38.709344], 'properties': {}}, 'id': '9a2776eb0c58266f', 'place_type': 'city'}
# {'full_name': 'Piscataway, NJ', 'geo': {'type': 'Feature', 'bbox': [-74.524236, 40.506013, -74.40873, 40.597526], 'properties': {}}, 'id': '01a0aa02181f66f1', 'place_type': 'city'}
# {'full_name': 'Joliet, IL', 'geo': {'type': 'Feature', 'bbox': [-88.294633, 41.444387, -87.99039, 41.5947247], 'properties': {}}, 'id': '741e21eeea82f00a', 'place_type': 'city'}
# {'full_name': 'Lathrop, CA', 'geo': {'type': 'Feature', 'bbox': [-121.326808, 37.787451, -121.261674, 37.855687], 'properties': {}}, 'id': '2e15ebed23598d88', 'place_type': 'city'}
# {'full_name': 'Santa Ana, CA', 'geo': {'type': 'Feature', 'bbox': [-117.944051, 33.691774, -117.830826, 33.78821], 'properties': {}}, 'id': '0562e9e53cddf6ec', 'place_type': 'city'}
# {'full_name': 'Santa Clarita, CA', 'geo': {'type': 'Feature', 'bbox': [-118.6278742, 34.3474831, -118.3786434, 34.483779], 'properties': {}}, 'id': 'f9c0877820b7848a', 'place_type': 'city'}
# {'full_name': 'Bellevue, ID', 'geo': {'type': 'Feature', 'bbox': [-114.273687, 43.450713, -114.247744, 43.479954], 'properties': {}}, 'id': 'e49f3aec10eee60c', 'place_type': 'city'}
# {'full_name': 'Ballwin, MO', 'geo': {'type': 'Feature', 'bbox': [-90.59217, 38.54757, -90.509959, 38.624853], 'properties': {}}, 'id': 'cc1dc38105ac44d4', 'place_type': 'city'}
# {'full_name': 'Ely, MN', 'geo': {'type': 'Feature', 'bbox': [-91.878951, 47.891311, -91.82721, 47.919073], 'properties': {}}, 'id': '53f616888c86d431', 'place_type': 'city'}
# {'full_name': 'North Charleston, SC', 'geo': {'type': 'Feature', 'bbox': [-80.1575903, 32.829336, -79.934288, 32.9995131], 'properties': {}}, 'id': '18df13e4a5a670b5', 'place_type': 'city'}
# {'full_name': 'Hermosa Beach, CA', 'geo': {'type': 'Feature', 'bbox': [-118.4095788, 33.8518504, -118.3848663, 33.877823], 'properties': {}}, 'id': '4baf4d09759d33e4', 'place_type': 'city'}
# {'full_name': 'Boynton Beach, FL', 'geo': {'type': 'Feature', 'bbox': [-80.173447, 26.476484, -80.05236, 26.5904875], 'properties': {}}, 'id': '005e3661711a29a9', 'place_type': 'city'}
# {'full_name': 'Greenwood, SC', 'geo': {'type': 'Feature', 'bbox': [-82.1995713, 34.1498441, -82.108743, 34.2357843], 'properties': {}}, 'id': 'd6e407c4d4acecc3', 'place_type': 'city'}
# {'full_name': 'Lombard, IL', 'geo': {'type': 'Feature', 'bbox': [-88.0510152, 41.8319011, -87.9742996, 41.915092], 'properties': {}}, 'id': '9f3d755fe1a081a4', 'place_type': 'city'}
# {'full_name': 'Eugene, OR', 'geo': {'type': 'Feature', 'bbox': [-123.208615, 43.988281, -123.0361879, 44.142961], 'properties': {}}, 'id': '01241e9666cacdd2', 'place_type': 'city'}
# {'full_name': 'Tucson, AZ', 'geo': {'type': 'Feature', 'bbox': [-111.083219, 32.057802, -110.747928, 32.320979], 'properties': {}}, 'id': '013379ee5729a5e6', 'place_type': 'city'}
# {'full_name': 'Metairie, LA', 'geo': {'type': 'Feature', 'bbox': [-90.2376122, 29.968359, -90.119647, 30.034129], 'properties': {}}, 'id': '743df94d8dcb69a6', 'place_type': 'city'}
# {'full_name': 'Columbus, OH', 'geo': {'type': 'Feature', 'bbox': [-83.200169, 39.832013, -82.7713751, 40.157354], 'properties': {}}, 'id': '3df0e3eb1e91170b', 'place_type': 'city'}
# {'full_name': 'Concord, CA', 'geo': {'type': 'Feature', 'bbox': [-122.066245, 37.924231, -121.931044, 38.022423], 'properties': {}}, 'id': '8004d2bebcc13e8c', 'place_type': 'city'}
# {'full_name': 'Poland, OH', 'geo': {'type': 'Feature', 'bbox': [-80.630194, 40.987704, -80.519054, 41.055936], 'properties': {}}, 'id': 'bd46604b88949129', 'place_type': 'city'}
# {'full_name': 'Billerica, MA', 'geo': {'type': 'Feature', 'bbox': [-71.333619, 42.518932, -71.205499, 42.612781], 'properties': {}}, 'id': '01be8aa8195ae3b6', 'place_type': 'city'}
# {'full_name': 'Colorado, USA', 'geo': {'type': 'Feature', 'bbox': [-109.060257, 36.992427, -102.041524, 41.003445], 'properties': {}}, 'id': 'e21c8e4914eef2b3', 'place_type': 'admin'}
# {'full_name': 'Sylvania, OH', 'geo': {'type': 'Feature', 'bbox': [-83.77959, 41.658626, -83.644903, 41.7274627], 'properties': {}}, 'id': '01a11db77ef99e2a', 'place_type': 'city'}
# {'full_name': 'Burlington, IA', 'geo': {'type': 'Feature', 'bbox': [-91.167512, 40.763821, -91.094099, 40.858065], 'properties': {}}, 'id': '6515916567ad4b34', 'place_type': 'city'}
# {'full_name': 'Bakersfield, CA', 'geo': {'type': 'Feature', 'bbox': [-119.172179, 35.255821, -118.878147, 35.4379816], 'properties': {}}, 'id': '960993b9cfdffda9', 'place_type': 'city'}
